# %% [markdown]
# <a href="https://colab.research.google.com/github/LANDOSOUZA/Atividade_Somativa/blob/main/aula02_llama_groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install llama_index.llms.groq

# %%
from google.colab import userdata
GROQ_API = userdata.get('GROQ_API')

# %%
from llama_index.llms.groq import Groq

# %%
llm = Groq(model='llama-3.3-70b-versatile', api_key=GROQ_API)
response = llm.complete('Qual é a substância que dá o aroma do alecrim?')

# %%
response

# %%
paragrafos = response.text.split("\n\n")
for paragrafo in paragrafos:
    print(paragrafo)
    print()
# Out:
# A substância que dá o aroma característico do alecrim é o carvona. No entanto, o composto principal responsável pelo aroma e sabor do alecrim é o carvacrol, um fenol monoterpeno. O carvacrol é um óleo essencial encontrado nas folhas do alecrim (Rosmarinus officinalis) e é amplamente utilizado em culinária, medicina tradicional e aromaterapia devido às suas propriedades antioxidantes, anti-inflamatórias e antimicrobianas.
#
# O carvacrol é responsável pelo aroma herbáceo e ligeiramente amargo do alecrim, tornando-o uma erva popular para cozinhar carnes, legumes e outros pratos. Além disso, o carvacrol também tem sido estudado por suas potenciais propriedades de saúde, incluindo a capacidade de melhorar a memória e a cognição, além de ter efeitos neuroprotetores.
#
# ...
